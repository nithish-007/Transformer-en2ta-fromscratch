# %%
import torch 
from datasets import load_dataset
from torch import nn

# Login using e.g. `huggingface-cli login` to access this dataset
ds = load_dataset("jarvisvasu/english-to-colloquial-tamil")['train']

# %%
for i in ds:
    print(i)
    break
# Out:
# {'instruction': 'Translate provided English text into colloquial Tamil', 'input': 'Fourteen months later, a second calf was born.', 'output': '14 மாசம் கழிச்சு, ரெண்டாவது calf பிறந்துடுச்சு.'}

# %%
ds
# Out:
# Dataset({
#     features: ['instruction', 'input', 'output'],
#     num_rows: 15973
# })
